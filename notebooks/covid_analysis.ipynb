# %% [markdown]
# ## Covid variant analysis
# <a>https://www.ecdc.europa.eu/en/publications-data/data-virus-variants-covid-19-eueea</a>
#
# <a>https://www.ecdc.europa.eu/sites/default/files/documents/2021-04-19_Variable_Dictionary_and_Disclaimer_variant-data.pdf</a>

# %%
import pandas as pd
import os
import numpy as np
import datetime
import Utils

# %%
os.getcwd()
# Out:
# 'C:\\Users\\luca.rendina\\Alternative Workspace\\covid_analysis\\notebooks'

# %%
df = pd.read_csv ('../data/covid_variants_SNAPSHOT_17_01_22.csv')

# %% [markdown]
# https://www.who.int/en/activities/tracking-SARS-CoV-2-variants/

# %%
map_covid_variants = {
    "alpha":"B.1.1.7",
    "beta":"B.1.351",
    "gamma":"P.1",
    "delta":"B.1.617",
    "delta.1":"B.1.617.1",
    "delta.3":"B.1.617.3",
    "delta.2":"B.1.617.2",
    "omicron":"B.1.1.529",
    "lambda":"C.37",
    "mu":"B.1.621",
    "delta+":"AY.4.2",
    "ihu":"B.1.640",
    "ihu.2":"B.1.640.2"
}

# %%
for var, code in map_covid_variants.items():
    replace(df, "variant", code, var)

# %%
df.dropna().size
# Out:
# 536748

# %%
sum(df.country == "Italy")
# Out:
# 1969

# %%
df.columns
# Out:
# Index(['country', 'country_code', 'year_week', 'source', 'new_cases',
#        'number_sequenced', 'percent_cases_sequenced', 'valid_denominator',
#        'variant', 'number_detections_variant',
#        'number_sequenced_known_variant', 'percent_variant'],
#       dtype='object')

# %%
[ len(set(df[column])) for column in df.columns]
# Out:
# [30, 30, 66, 2, 1859, 1617, 633, 2, 24, 1607, 3781, 8515]

# %%
df_dropna = df.dropna()

# %%
df_dropna.size
# Out:
# 536748

# %%
df_italy = df_dropna[df_dropna.country == "Italy"]

# %%
set(df_italy.variant)
# Out:
# {'AT.1',
#  'B.1.1.7+E484K',
#  'B.1.427/B.1.429',
#  'B.1.525',
#  'B.1.526',
#  'B.1.616',
#  'B.1.620',
#  'C.1.2',
#  'Other',
#  'P.3',
#  'alpha',
#  'beta',
#  'delta',
#  'delta+',
#  'delta.1',
#  'delta.2',
#  'delta.3',
#  'gamma',
#  'ihu',
#  'lambda',
#  'mu',
#  'omicron'}

# %%
last_week = df.year_week.iloc[-1]

# %%
df_lastweek = df[df.year_week == last_week]

# %%
df_lastweek_it = df_lastweek[df_lastweek.country == "Italy"]

# %%
df_lastweek_it
# Out:
#       country country_code year_week  source  new_cases  number_sequenced  \
# 27390   Italy           IT   2021-52  GISAID     710929               417
# 27391   Italy           IT   2021-52  GISAID     710929               417
# 27392   Italy           IT   2021-52  GISAID     710929               417
# 27393   Italy           IT   2021-52  GISAID     710929               417
# 27394   Italy           IT   2021-52  GISAID     710929               417
# 27395   Italy           IT   2021-52  GISAID     710929               417
# 27396   Italy           IT   2021-52  GISAID     710929               417
# 27397   Italy           IT   2021-52  GISAID     710929               417
# 27398   Italy           IT   2021-52  GISAID     710929               417
# 27399   Italy           IT   2021-52  GISAID     710929               417
# 27400   Italy           IT   2021-52  GISAID     710929               417
# 27401   Italy           IT   2021-52  GISAID     710929               417
# 27402   Italy           IT   2021-52  GISAID     710929               417
# 27403   Italy           IT   2021-52  GISAID     710929               417
# 27404   Italy           IT   2021-52  GISAID     710929               417
# 27405   Italy           IT   2021-52  GISAID     710929               417
# 27406   Italy           IT   2021-52  GISAID     710929               417
# 27407   Italy           IT   2021-52  GISAID     710929               417
# 27408   Italy           IT   2021-52  GISAID     710929               417
# 27409   Italy           IT   2021-52  GISAID     710929               417
# 27410   Italy           IT   2021-52  GISAID     710929               417
# 27411   Italy           IT   2021-52  GISAID     710929               417
# 27412   Italy           IT   2021-52  GISAID     710929               417
# 27856   Italy           IT   2021-52   TESSy     710929               532
# 27857   Italy           IT   2021-52   TESSy     710929               532
# 27858   Italy           IT   2021-52   TESSy     710929               532
# 27859   Italy           IT   2021-52   TESSy     710929               532
# 27860   Italy           IT   2021-52   TESSy     710929               532
# 27861   Italy           IT   2021-52   TESSy     710929               532
# 27862   Italy           IT   2021-52   TESSy     710929               532
# 27863   Italy           IT   2021-52   TESSy     710929               532
#
#        percent_cases_sequenced valid_denominator          variant  \
# 27390                      0.1               Yes             AT.1
# 27391                      0.1               Yes           delta+
# 27392                      0.1               Yes          omicron
# 27393                      0.1               Yes            alpha
# 27394                      0.1               Yes    B.1.1.7+E484K
# 27395                      0.1               Yes             beta
# 27396                      0.1               Yes  B.1.427/B.1.429
# 27397                      0.1               Yes          B.1.525
# 27398                      0.1               Yes          B.1.526
# 27399                      0.1               Yes          B.1.616
# 27400                      0.1               Yes            delta
# 27401                      0.1               Yes          delta.1
# 27402                      0.1               Yes          delta.2
# 27403                      0.1               Yes          delta.3
# 27404                      0.1               Yes          B.1.620
# 27405                      0.1               Yes               mu
# 27406                      0.1               Yes              ihu
# 27407                      0.1               Yes            C.1.2
# 27408                      0.1               Yes           lambda
# 27409                      0.1               Yes            gamma
# 27410                      0.1               Yes              P.3
# 27411                      0.1               Yes              UNK
# 27412                      0.1               Yes            Other
# 27856                      0.1               Yes          omicron
# 27857                      0.1               Yes            alpha
# 27858                      0.1               Yes          B.1.525
# 27859                      0.1               Yes            delta
# 27860                      0.1               Yes          delta.1
# 27861                      0.1               Yes          delta.2
# 27862                      0.1               Yes            gamma
# 27863                      0.1               Yes            Other
#
#        number_detections_variant  number_sequenced_known_variant  \
# 27390                          0                           399.0
# 27391                          2                           399.0
# 27392                        251                           399.0
# 27393                          0                           399.0
# 27394                          0                           399.0
# 27395                          0                           399.0
# 27396                          0                           399.0
# 27397                          0                           399.0
# 27398                          0                           399.0
# 27399                          0                           399.0
# 27400                          0                           399.0
# 27401                          0                           399.0
# 27402                        146                           399.0
# 27403                          0                           399.0
# 27404                          0                           399.0
# 27405                          0                           399.0
# 27406                          0                           399.0
# 27407                          0                           399.0
# 27408                          0                           399.0
# 27409                          0                           399.0
# 27410                          0                           399.0
# 27411                         19                             NaN
# 27412                          0                           399.0
# 27856                        110                           532.0
# 27857                         52                           532.0
# 27858                          1                           532.0
# 27859                          0                           532.0
# 27860                          1                           532.0
# 27861                         63                           532.0
# 27862                          2                           532.0
# 27863                        303                           532.0
#
#        percent_variant
# 27390              0.0
# 27391              0.5
# 27392             62.9
# 27393              0.0
# 27394              0.0
# 27395              0.0
# 27396              0.0
# 27397              0.0
# 27398              0.0
# 27399              0.0
# 27400              0.0
# 27401              0.0
# 27402             36.6
# 27403              0.0
# 27404              0.0
# 27405              0.0
# 27406              0.0
# 27407              0.0
# 27408              0.0
# 27409              0.0
# 27410              0.0
# 27411              NaN
# 27412              0.0
# 27856             20.7
# 27857              9.8
# 27858              0.2
# 27859              0.0
# 27860              0.2
# 27861             11.8
# 27862              0.4
# 27863             57.0

# %%
set(df.variant)
# Out:
# {'AT.1',
#  'B.1.1.7+E484K',
#  'B.1.427/B.1.429',
#  'B.1.525',
#  'B.1.526',
#  'B.1.616',
#  'B.1.620',
#  'C.1.2',
#  'Other',
#  'P.3',
#  'SGTF',
#  'UNK',
#  'alpha',
#  'beta',
#  'delta',
#  'delta+',
#  'delta.1',
#  'delta.2',
#  'delta.3',
#  'gamma',
#  'ihu',
#  'lambda',
#  'mu',
#  'omicron'}

# %%
print(fromWeekToDate(last_week))
# Out:
# ['2021-12-27', '2022-01-02']

# %%
help(fromWeekToDate)
# Out:
# Help on function fromWeekToDate in module __main__:
#
# fromWeekToDate(week, weekFormat='%Y-%W-%w', dateFormat='%Y-%m-%d')
